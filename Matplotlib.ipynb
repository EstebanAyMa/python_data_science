# %%
from math import tau
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import default_rng

# %%
x = np.linspace(0, tau, 100)

fig, ax = plt.subplots()

ax.set_xticks([0, tau/4, tau/2, 3*tau/4, tau])
ax.set_yticks([-1, -1/2, 0, 1/2, 1])
plt.grid(True)

ax.set_xticklabels([r"$0$", r"$\tau/4$", r"$\tau/2$", r"$3\tau/4$", r"$\tau$"])
ax.set_yticklabels([r"$-1$", r"$-1/2$", r"$0$", r"$1/2$", r"$1$"])

ax.set_title("One period of cosine and sine", fontsize=16)
ax.set_xlabel(r"$\theta$", fontsize=16)
ax.set_ylabel(r"$f(\theta)$", fontsize=16)

ax.annotate(r"$\cos\theta$", xy=(1.75, -0.3), xytext=(0.5, -0.75),
            arrowprops={"facecolor": "black", "width": 1}, fontsize=16)
ax.annotate(r"$\sin\theta$", xy=(2.75, 0.5), xytext=(3.5, 0.75),
            arrowprops={"facecolor": "black", "width": 1}, fontsize=16)
ax.annotate(r"$\cos(x - \theta)$", xy=(5, -0.5), xytext=(5.0, -0.1),
            arrowprops={"facecolor": "black", "width": 1}, fontsize=16)


fig.set_dpi(150)

ax.plot(x, np.cos(x), color="red", linestyle="dashed")
ax.plot(x, np.sin(x), color="blue", linestyle="dotted")
ax.plot(x, np.cos(x - tau/8), color="orange", linestyle="dashdot")
plt.show()

# %%
rng = default_rng()
n_pts = 50
x = rng.standard_normal(n_pts)
x
# Out:
# array([ 0.0068889 ,  1.14697664,  0.28177976, -0.78158187,  1.32734512,
#        -0.34651301,  0.67368889, -2.80336135, -0.21406112,  0.30397416,
#        -0.40163533,  0.45568459, -0.24246713,  0.38474572,  0.80954499,
#        -1.51183488, -0.2602002 ,  0.67001075, -0.7623034 ,  2.76808812,
#        -1.40629077, -0.10986246, -0.18724656,  1.18192472,  1.28871478,
#         1.25408644,  0.12152103,  0.19347237,  1.7089212 ,  0.22883267,
#         0.07720806, -0.59950634,  1.69385188, -0.62051341, -0.9203376 ,
#        -1.71003129,  0.08596372,  0.4555722 , -0.40381826,  0.54628847,
#        -0.23233086, -0.80945001, -0.66364032, -1.01447862,  0.76617971,
#        -0.09095568,  0.79941676,  0.58822486, -0.14189778, -1.36973176])

# %%
y = 5*x + rng.standard_normal(n_pts)

# %%
fig, ax = plt.subplots()
ax.scatter(x, y)
ax.set_title("Scatter Plot Example")
ax.set_xlabel("Inputs")
ax.set_ylabel("f (x)")
plt.show()

# %%
values = rng.standard_normal(1000)

# %%
fig, ax = plt.subplots()
ax.set_title("Histogram with 10 bins")
ax.hist(values)
plt.show()

# %%
fig, ax = plt.subplots()
ax.set_title("Histogram with 20 bins")
ax.hist(values, bins=20)
plt.show()

# %%
 x = np.linspace(0, tau, 100)
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle(r"Vertically stacked plots of $\cos\theta$ and $\sin\theta$.")
ax1.plot(x, np.cos(x))
ax2.plot(x, np.sin(x))
